# %% [markdown]
# # Train and deploy a neuronal network in the AWS cloud
#
# In the following notebook is shown how to train and deploy a Keras Neuronal Network model. This Neuronal Network is going to serve as an inference engine endpoint at AWS Sagemaker. The model is going to be triggered from a Lambda function when new values from a field sensor arrives.
#
#
# As field soft sensor, a [RMG/941](https://www.ssv-embedded.de/produkte/rmg941.php) is used.

# %% [markdown]
# ### Step 1:
#
# Import general libraries and import files from S3. The files are stored in a compressed .tgz file. These files where uploaded to S3 with the PyDSlog app from the RMG/941 gateway.
#
# The Bucket is the same as the defined when the files were uploaded to S3 from the soft sensor and the prefix is a timestamp that is used at the same time as folder name.

# %%
import json
import numpy as np
import pandas as pd
import boto3
import tarfile
import sagemaker

BUCKET = "<your bucket name>" 
PREFIX = "<path in bucket>"

# download files from s3 to sagemaker
s3 = boto3.client('s3')
s3.download_file(BUCKET, PREFIX+".tgz", PREFIX+".tgz")

# %% [markdown]
# Since the files are loaded in a compressed .tgz file, they must be unpacked before the signals can be read.
# The config.cfg file stores configurations parameters like frequency of the sensor and the length of the signals. These configurations are needed for the FFT transformation.

# %%
# extract tar files
tar = tarfile.open(PREFIX+".tgz")
tar.extractall()
tar.close()

# read config
with open(PREFIX+"/"+"config.cfg") as f:
    config = str(f.read())
    
config = json.loads(config)

sig      = bool(config["save_as_signal"])
channels = list(config["channels"])
freq     = int(config["frequency"])
N        = int(config["frame_size"])

X_FILES = ["x_"+n+"_.csv" for n in channels]


# read signals into numpy arrays
signals = []
for file in X_FILES:
    data_location = PREFIX+"/"+file
    s = np.array(pd.read_csv(data_location, header=None, index_col=None))
    signals.append(s)
signals = np.transpose(np.array(signals), (1, 0, 2))

# read labels into numpy arrays
Y_FILE = "y_.csv"
data_location = PREFIX+"/"+Y_FILE
labels = np.array(pd.read_csv(data_location, header=None, index_col=None))
labels = np.squeeze(labels)


# print shapes
print("Labels shape")
print(labels.shape)
print("Signals shape")
print(signals.shape)

print("Different labels in dataset:")
diff_labels = np.unique(labels)
print(diff_labels)
# Out:
# Labels shape
# (398,)
# Signals shape
# (398, 6, 600)
# Different labels in dataset:
# [0 1 2]

# %% [markdown]
# Configurations are loaded with the signal files in the AWS S3 Bucket. You can see the channels, Data source, frequency and the length of the signals.

# %%
print(config)
# Out:
# {'frequency': '300', 'save_as_signal': 'True', 'frame_size': '600', 'channels': ['ACCX', 'ACCY', 'ACCZ', 'GYRX', 'GYRY', 'GYRZ'], 'labeled': 'True', 'source': 'MLS/160A'}

# %% [markdown]
# ### Step 2:

# %% [markdown]
# See how the data looks like. It is possible to see differences between the signals of differents classes?

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=6, ncols=1,figsize=(20, 15))

signals_to_show = [10, 200, 350]
colors = ["red", "orange", "green"]
titles = ["Acc X", "Acc Y", "Acc Z", "Ang X", "Ang Y", "Ang Z"]

for c in range(signals.shape[1]):
    for s in range(len(signals_to_show)):
        ax[c].plot(signals[signals_to_show[s],c,:], linestyle='-', color=colors[s], 
                   label="label "+str(labels[signals_to_show[s]]))
    ax[c].legend(loc='lower right')
    ax[c].set_title(titles[c], fontsize=16)
    ax[c].set_xlabel('Time', fontsize=10)
    ax[c].set_ylabel('Amplitude', fontsize=10)

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Step 3:
# Transform the dataset. since the datasets are signals, a [FFT](https://en.wikipedia.org/wiki/Fast_Fourier_transform) is going to be used for the transformation. These transformations are used as Features.

# %%
import scipy.signal as signal
from scipy.fftpack import fft

def do_FFTs(values, freq, length, delete_offset=True):
    
    period = 1.0/freq

    _ffts = []
    for n in range(0, values.shape[0]):
        _c = []
        for c in range(0, values.shape[1]):

            v = values[n,c,:]

            if delete_offset:
                v = signal.detrend(v, type == 'constant')

            freq_v = np.linspace(0.0, 1.0 / (2.0 * period), length // 2)
            fft_v_ = fft(v)
            fft_v = 2.0 / length * np.abs(fft_v_[0:length // 2])

            xy_v = np.vstack((freq_v, fft_v)).T
            _c.append(xy_v)
        _ffts.append(_c)      
        
    return np.array(_ffts)


fft_values = do_FFTs(signals, freq, N,)

# dimensions are (n of ffts, n of components, length of ffts, time and amplitude values)
#print("FFTs shape : ",fft_values.shape)

fft_amplitudes = fft_values[:,:,:,1]
print("FFTs amplitudes shape : ",fft_amplitudes.shape)
# Out:
# FFTs amplitudes shape :  (398, 6, 300)

# %% [markdown]
# ### Step 4:

# %% [markdown]
# Visualize how the transformations looks like. See if there are differences between the different classes.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=6, ncols=1,figsize=(20, 15))

#signals_to_show = [10, 180, 390]
colors = ["red", "orange", "green"]
titles = ["Acc X", "Acc Y", "Acc Z", "Ang X", "Ang Y", "Ang Z"]

for c in range(signals.shape[1]):
    for s in range(len(signals_to_show)):
        ax[c].plot(fft_amplitudes[signals_to_show[s],c,:], linestyle='-', color=colors[s], 
                   label="label "+str(labels[signals_to_show[s]]))
    ax[c].legend(loc='lower right')
    ax[c].set_title(titles[c], fontsize=16)
    ax[c].set_xlabel('Frequency [Hz]', fontsize=10)
    ax[c].set_ylabel('Amplitude', fontsize=10)

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Step 5:
# Train and test split.
# Split the Features in a training dataset and a test dataset. Here the split is 40% for testing and 60% for training.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(fft_amplitudes, labels, test_size=0.4,
                                                    random_state=42, stratify=labels)

x_train = x_train.reshape(x_train.shape[0],x_train.shape[1]*x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1]*x_test.shape[2])

print("train shape: ",x_train.shape)
print("train labels shape: ",y_train.shape)
print("test shape: ",x_test.shape)
print("labels shape: ",y_test.shape)
# Out:
# train shape:  (238, 1800)
# train labels shape:  (238,)
# test shape:  (160, 1800)
# labels shape:  (160,)

# %% [markdown]
# ### Step 6:
# generate a model

# %%
# Import Tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Change the label to fit the NN. Converts a class vector (integers) to binary class matrix.
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(y_train.shape)
print(y_test.shape)


dimensions_in = x_train.shape[1]
dimensions_out = y_train.shape[1]

# Define neuronal network and train.
model = keras.Sequential()
model.add(layers.Dense(100, input_shape=(dimensions_in,), activation='sigmoid'))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(100, activation='sigmoid'))
model.add(layers.Dense(dimensions_out, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

print(model.summary())

history = model.fit(x_train, y_train, batch_size=100, epochs=250, 
          validation_data=(x_test, y_test), verbose=1)
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/__init__.py:1467: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# (238, 3)
# (160, 3)
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               180100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 190,503
# Trainable params: 190,503
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 238 samples, validate on 160 samples
# WARNING:tensorflow:OMP_NUM_THREADS is no longer used by the default Keras config. To configure the number of threads, use tf.config.threading APIs.
# Epoch 1/250
# 238/238 [==============================] - 0s 2ms/sample - loss: 1.0521 - acc: 0.5210 - val_loss: 0.9874 - val_acc: 0.5813
# Epoch 2/250
# 238/238 [==============================] - 0s 67us/sample - loss: 0.9416 - acc: 0.6849 - val_loss: 0.8828 - val_acc: 0.7437
# Epoch 3/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.8498 - acc: 0.7563 - val_loss: 0.7990 - val_acc: 0.7625
# Epoch 4/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.7803 - acc: 0.7647 - val_loss: 0.7382 - val_acc: 0.7563
# Epoch 5/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.7103 - acc: 0.7689 - val_loss: 0.6596 - val_acc: 0.7750
# Epoch 6/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.6389 - acc: 0.7815 - val_loss: 0.5970 - val_acc: 0.7688
# Epoch 7/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.5578 - acc: 0.8109 - val_loss: 0.5337 - val_acc: 0.8000
# Epoch 8/250
# 238/238 [==============================] - 0s 64us/sample - loss: 0.5092 - acc: 0.8445 - val_loss: 0.4983 - val_acc: 0.8500
# Epoch 9/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.4712 - acc: 0.8697 - val_loss: 0.4529 - val_acc: 0.8938
# Epoch 10/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.4160 - acc: 0.9034 - val_loss: 0.3932 - val_acc: 0.9250
# Epoch 11/250
# 238/238 [==============================] - 0s 66us/sample - loss: 0.3661 - acc: 0.9622 - val_loss: 0.3576 - val_acc: 0.9375
# Epoch 12/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.3294 - acc: 0.9580 - val_loss: 0.3305 - val_acc: 0.9500
# Epoch 13/250
# 238/238 [==============================] - 0s 66us/sample - loss: 0.3057 - acc: 0.9748 - val_loss: 0.3010 - val_acc: 0.9438
# Epoch 14/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.2663 - acc: 0.9706 - val_loss: 0.2604 - val_acc: 0.9563
# Epoch 15/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.2309 - acc: 0.9832 - val_loss: 0.2322 - val_acc: 0.9625
# Epoch 16/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.2048 - acc: 0.9790 - val_loss: 0.2147 - val_acc: 0.9563
# Epoch 17/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.1823 - acc: 0.9790 - val_loss: 0.1920 - val_acc: 0.9750
# Epoch 18/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.1612 - acc: 0.9874 - val_loss: 0.1696 - val_acc: 0.9812
# Epoch 19/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.1439 - acc: 0.9916 - val_loss: 0.1562 - val_acc: 0.9875
# Epoch 20/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.1337 - acc: 0.9916 - val_loss: 0.1348 - val_acc: 0.9937
# Epoch 21/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.1166 - acc: 0.9958 - val_loss: 0.1133 - val_acc: 0.9937
# Epoch 22/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0946 - acc: 1.0000 - val_loss: 0.1061 - val_acc: 0.9875
# Epoch 23/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.0901 - acc: 0.9874 - val_loss: 0.1046 - val_acc: 0.9812
# Epoch 24/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.0820 - acc: 0.9916 - val_loss: 0.1041 - val_acc: 0.9812
# Epoch 25/250
# 238/238 [==============================] - 0s 66us/sample - loss: 0.0776 - acc: 0.9958 - val_loss: 0.0918 - val_acc: 0.9875
# Epoch 26/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0709 - acc: 0.9958 - val_loss: 0.0859 - val_acc: 0.9937
# Epoch 27/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0650 - acc: 0.9958 - val_loss: 0.0806 - val_acc: 0.9937
# Epoch 28/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0571 - acc: 0.9958 - val_loss: 0.0663 - val_acc: 0.9937
# Epoch 29/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0533 - acc: 1.0000 - val_loss: 0.0633 - val_acc: 0.9937
# Epoch 30/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0479 - acc: 1.0000 - val_loss: 0.0613 - val_acc: 0.9937
# Epoch 31/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0452 - acc: 1.0000 - val_loss: 0.0590 - val_acc: 0.9937
# Epoch 32/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0434 - acc: 1.0000 - val_loss: 0.0559 - val_acc: 0.9937
# Epoch 33/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0421 - acc: 0.9958 - val_loss: 0.0525 - val_acc: 0.9937
# Epoch 34/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.0389 - acc: 0.9958 - val_loss: 0.0467 - val_acc: 0.9937
# Epoch 35/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0365 - acc: 1.0000 - val_loss: 0.0469 - val_acc: 0.9875
# Epoch 36/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0320 - acc: 1.0000 - val_loss: 0.0470 - val_acc: 0.9875
# Epoch 37/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0349 - acc: 0.9958 - val_loss: 0.0462 - val_acc: 0.9875
# Epoch 38/250
# 238/238 [==============================] - 0s 75us/sample - loss: 0.0306 - acc: 1.0000 - val_loss: 0.0485 - val_acc: 0.9875
# Epoch 39/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0285 - acc: 1.0000 - val_loss: 0.0477 - val_acc: 0.9875
# Epoch 40/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.0256 - acc: 1.0000 - val_loss: 0.0474 - val_acc: 0.9875
# Epoch 41/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0273 - acc: 0.9958 - val_loss: 0.0454 - val_acc: 0.9875
# Epoch 42/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0222 - acc: 1.0000 - val_loss: 0.0423 - val_acc: 0.9875
# Epoch 43/250
# 238/238 [==============================] - 0s 75us/sample - loss: 0.0247 - acc: 0.9958 - val_loss: 0.0408 - val_acc: 0.9875
# Epoch 44/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0230 - acc: 0.9958 - val_loss: 0.0389 - val_acc: 0.9875
# Epoch 45/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0206 - acc: 1.0000 - val_loss: 0.0370 - val_acc: 0.9875
# Epoch 46/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0196 - acc: 1.0000 - val_loss: 0.0346 - val_acc: 0.9875
# Epoch 47/250
# 238/238 [==============================] - 0s 80us/sample - loss: 0.0205 - acc: 0.9958 - val_loss: 0.0339 - val_acc: 0.9875
# Epoch 48/250
# 238/238 [==============================] - 0s 84us/sample - loss: 0.0185 - acc: 1.0000 - val_loss: 0.0333 - val_acc: 0.9875
# Epoch 49/250
# 238/238 [==============================] - 0s 87us/sample - loss: 0.0177 - acc: 1.0000 - val_loss: 0.0330 - val_acc: 0.9875
# Epoch 50/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0155 - acc: 1.0000 - val_loss: 0.0331 - val_acc: 0.9875
# Epoch 51/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0177 - acc: 0.9958 - val_loss: 0.0325 - val_acc: 0.9875
# Epoch 52/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0161 - acc: 1.0000 - val_loss: 0.0349 - val_acc: 0.9875
# Epoch 53/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0148 - acc: 1.0000 - val_loss: 0.0348 - val_acc: 0.9875
# Epoch 54/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0141 - acc: 1.0000 - val_loss: 0.0343 - val_acc: 0.9875
# Epoch 55/250
# 238/238 [==============================] - 0s 66us/sample - loss: 0.0155 - acc: 0.9958 - val_loss: 0.0330 - val_acc: 0.9875
# Epoch 56/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0140 - acc: 1.0000 - val_loss: 0.0311 - val_acc: 0.9875
# Epoch 57/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0132 - acc: 1.0000 - val_loss: 0.0317 - val_acc: 0.9875
# Epoch 58/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0136 - acc: 1.0000 - val_loss: 0.0309 - val_acc: 0.9875
# Epoch 59/250
# 238/238 [==============================] - 0s 80us/sample - loss: 0.0132 - acc: 0.9958 - val_loss: 0.0311 - val_acc: 0.9875
# Epoch 60/250
# 238/238 [==============================] - 0s 84us/sample - loss: 0.0116 - acc: 1.0000 - val_loss: 0.0320 - val_acc: 0.9875
# Epoch 61/250
# 238/238 [==============================] - 0s 76us/sample - loss: 0.0114 - acc: 1.0000 - val_loss: 0.0334 - val_acc: 0.9875
# Epoch 62/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0100 - acc: 1.0000 - val_loss: 0.0325 - val_acc: 0.9875
# Epoch 63/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0102 - acc: 1.0000 - val_loss: 0.0328 - val_acc: 0.9875
# Epoch 64/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0104 - acc: 1.0000 - val_loss: 0.0322 - val_acc: 0.9937
# Epoch 65/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0094 - acc: 1.0000 - val_loss: 0.0326 - val_acc: 0.9937
# Epoch 66/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0087 - acc: 1.0000 - val_loss: 0.0346 - val_acc: 0.9875
# Epoch 67/250
# 238/238 [==============================] - 0s 83us/sample - loss: 0.0096 - acc: 1.0000 - val_loss: 0.0347 - val_acc: 0.9875
# Epoch 68/250
# 238/238 [==============================] - 0s 80us/sample - loss: 0.0081 - acc: 1.0000 - val_loss: 0.0353 - val_acc: 0.9875
# Epoch 69/250
# 238/238 [==============================] - 0s 80us/sample - loss: 0.0089 - acc: 1.0000 - val_loss: 0.0358 - val_acc: 0.9875
# Epoch 70/250
# 238/238 [==============================] - 0s 82us/sample - loss: 0.0112 - acc: 0.9958 - val_loss: 0.0351 - val_acc: 0.9875
# Epoch 71/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0078 - acc: 1.0000 - val_loss: 0.0351 - val_acc: 0.9875
# Epoch 72/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0089 - acc: 1.0000 - val_loss: 0.0374 - val_acc: 0.9812
# Epoch 73/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0076 - acc: 1.0000 - val_loss: 0.0390 - val_acc: 0.9812
# Epoch 74/250
# 238/238 [==============================] - 0s 81us/sample - loss: 0.0084 - acc: 1.0000 - val_loss: 0.0402 - val_acc: 0.9812
# Epoch 75/250
# 238/238 [==============================] - 0s 85us/sample - loss: 0.0072 - acc: 1.0000 - val_loss: 0.0403 - val_acc: 0.9812
# Epoch 76/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0076 - acc: 1.0000 - val_loss: 0.0406 - val_acc: 0.9812
# Epoch 77/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0067 - acc: 1.0000 - val_loss: 0.0405 - val_acc: 0.9812
# Epoch 78/250
# 238/238 [==============================] - 0s 81us/sample - loss: 0.0089 - acc: 0.9958 - val_loss: 0.0415 - val_acc: 0.9812
# Epoch 79/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0067 - acc: 1.0000 - val_loss: 0.0430 - val_acc: 0.9812
# Epoch 80/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0061 - acc: 1.0000 - val_loss: 0.0427 - val_acc: 0.9812
# Epoch 81/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0073 - acc: 1.0000 - val_loss: 0.0429 - val_acc: 0.9812
# Epoch 82/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0059 - acc: 1.0000 - val_loss: 0.0432 - val_acc: 0.9812
# Epoch 83/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0057 - acc: 1.0000 - val_loss: 0.0435 - val_acc: 0.9812
# Epoch 84/250
# 238/238 [==============================] - 0s 66us/sample - loss: 0.0064 - acc: 1.0000 - val_loss: 0.0459 - val_acc: 0.9812
# Epoch 85/250
# 238/238 [==============================] - 0s 84us/sample - loss: 0.0075 - acc: 1.0000 - val_loss: 0.0496 - val_acc: 0.9812
# Epoch 86/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0059 - acc: 1.0000 - val_loss: 0.0501 - val_acc: 0.9812
# Epoch 87/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0053 - acc: 1.0000 - val_loss: 0.0508 - val_acc: 0.9812
# Epoch 88/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0063 - acc: 1.0000 - val_loss: 0.0515 - val_acc: 0.9812
# Epoch 89/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0055 - acc: 1.0000 - val_loss: 0.0530 - val_acc: 0.9812
# Epoch 90/250
# 238/238 [==============================] - 0s 75us/sample - loss: 0.0056 - acc: 1.0000 - val_loss: 0.0553 - val_acc: 0.9812
# Epoch 91/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.0054 - acc: 1.0000 - val_loss: 0.0563 - val_acc: 0.9812
# Epoch 92/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0072 - acc: 1.0000 - val_loss: 0.0546 - val_acc: 0.9812
# Epoch 93/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0050 - acc: 1.0000 - val_loss: 0.0543 - val_acc: 0.9812
# Epoch 94/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.0049 - acc: 1.0000 - val_loss: 0.0540 - val_acc: 0.9812
# Epoch 95/250
# 238/238 [==============================] - 0s 80us/sample - loss: 0.0047 - acc: 1.0000 - val_loss: 0.0540 - val_acc: 0.9812
# Epoch 96/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0051 - acc: 1.0000 - val_loss: 0.0544 - val_acc: 0.9812
# Epoch 97/250
# 238/238 [==============================] - 0s 82us/sample - loss: 0.0044 - acc: 1.0000 - val_loss: 0.0542 - val_acc: 0.9812
# Epoch 98/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0049 - acc: 1.0000 - val_loss: 0.0506 - val_acc: 0.9812
# Epoch 99/250
# 238/238 [==============================] - 0s 82us/sample - loss: 0.0048 - acc: 1.0000 - val_loss: 0.0479 - val_acc: 0.9812
# Epoch 100/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0050 - acc: 1.0000 - val_loss: 0.0479 - val_acc: 0.9812
# Epoch 101/250
# 238/238 [==============================] - 0s 86us/sample - loss: 0.0042 - acc: 1.0000 - val_loss: 0.0485 - val_acc: 0.9812
# Epoch 102/250
# 238/238 [==============================] - 0s 76us/sample - loss: 0.0051 - acc: 1.0000 - val_loss: 0.0486 - val_acc: 0.9812
# Epoch 103/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0067 - acc: 1.0000 - val_loss: 0.0474 - val_acc: 0.9812
# Epoch 104/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0052 - acc: 1.0000 - val_loss: 0.0479 - val_acc: 0.9812
# Epoch 105/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0489 - val_acc: 0.9812
# Epoch 106/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0043 - acc: 1.0000 - val_loss: 0.0496 - val_acc: 0.9812
# Epoch 107/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0047 - acc: 1.0000 - val_loss: 0.0510 - val_acc: 0.9812
# Epoch 108/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0044 - acc: 1.0000 - val_loss: 0.0509 - val_acc: 0.9812
# Epoch 109/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0039 - acc: 1.0000 - val_loss: 0.0523 - val_acc: 0.9812
# Epoch 110/250
# 238/238 [==============================] - 0s 83us/sample - loss: 0.0042 - acc: 1.0000 - val_loss: 0.0524 - val_acc: 0.9812
# Epoch 111/250
# 238/238 [==============================] - 0s 86us/sample - loss: 0.0040 - acc: 1.0000 - val_loss: 0.0512 - val_acc: 0.9812
# Epoch 112/250
# 238/238 [==============================] - 0s 81us/sample - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0516 - val_acc: 0.9812
# Epoch 113/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0037 - acc: 1.0000 - val_loss: 0.0521 - val_acc: 0.9812
# Epoch 114/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0037 - acc: 1.0000 - val_loss: 0.0523 - val_acc: 0.9812
# Epoch 115/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0035 - acc: 1.0000 - val_loss: 0.0526 - val_acc: 0.9812
# Epoch 116/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.0038 - acc: 1.0000 - val_loss: 0.0528 - val_acc: 0.9812
# Epoch 117/250
# 238/238 [==============================] - 0s 75us/sample - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0529 - val_acc: 0.9812
# Epoch 118/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0539 - val_acc: 0.9812
# Epoch 119/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0555 - val_acc: 0.9812
# Epoch 120/250
# 238/238 [==============================] - 0s 83us/sample - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0563 - val_acc: 0.9812
# Epoch 121/250
# 238/238 [==============================] - 0s 76us/sample - loss: 0.0038 - acc: 1.0000 - val_loss: 0.0572 - val_acc: 0.9812
# Epoch 122/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0566 - val_acc: 0.9812
# Epoch 123/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0548 - val_acc: 0.9812
# Epoch 124/250
# 238/238 [==============================] - 0s 83us/sample - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0547 - val_acc: 0.9812
# Epoch 125/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0532 - val_acc: 0.9812
# Epoch 126/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0527 - val_acc: 0.9812
# Epoch 127/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0523 - val_acc: 0.9812
# Epoch 128/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0522 - val_acc: 0.9812
# Epoch 129/250
# 238/238 [==============================] - 0s 80us/sample - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0525 - val_acc: 0.9812
# Epoch 130/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0557 - val_acc: 0.9812
# Epoch 131/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0555 - val_acc: 0.9812
# Epoch 132/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0531 - val_acc: 0.9812
# Epoch 133/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0530 - val_acc: 0.9812
# Epoch 134/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0529 - val_acc: 0.9812
# Epoch 135/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0534 - val_acc: 0.9812
# Epoch 136/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0548 - val_acc: 0.9812
# Epoch 137/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0561 - val_acc: 0.9812
# Epoch 138/250
# 238/238 [==============================] - 0s 67us/sample - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0573 - val_acc: 0.9812
# Epoch 139/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0576 - val_acc: 0.9812
# Epoch 140/250
# 238/238 [==============================] - 0s 67us/sample - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0581 - val_acc: 0.9812
# Epoch 141/250
# 238/238 [==============================] - 0s 84us/sample - loss: 0.0037 - acc: 1.0000 - val_loss: 0.0579 - val_acc: 0.9812
# Epoch 142/250
# 238/238 [==============================] - 0s 81us/sample - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0583 - val_acc: 0.9812
# Epoch 143/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0592 - val_acc: 0.9812
# Epoch 144/250
# 238/238 [==============================] - 0s 67us/sample - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0595 - val_acc: 0.9812
# Epoch 145/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0591 - val_acc: 0.9812
# Epoch 146/250
# 238/238 [==============================] - 0s 75us/sample - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0592 - val_acc: 0.9812
# Epoch 147/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0594 - val_acc: 0.9812
# Epoch 148/250
# 238/238 [==============================] - 0s 88us/sample - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0594 - val_acc: 0.9812
# Epoch 149/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0594 - val_acc: 0.9812
# Epoch 150/250
# 238/238 [==============================] - 0s 66us/sample - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0593 - val_acc: 0.9812
# Epoch 151/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0594 - val_acc: 0.9812
# Epoch 152/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0591 - val_acc: 0.9812
# Epoch 153/250
# 238/238 [==============================] - 0s 87us/sample - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0587 - val_acc: 0.9812
# Epoch 154/250
# 238/238 [==============================] - 0s 66us/sample - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0585 - val_acc: 0.9812
# Epoch 155/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0586 - val_acc: 0.9812
# Epoch 156/250
# 238/238 [==============================] - 0s 76us/sample - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0589 - val_acc: 0.9812
# Epoch 157/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0590 - val_acc: 0.9812
# Epoch 158/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0593 - val_acc: 0.9812
# Epoch 159/250
# 238/238 [==============================] - 0s 76us/sample - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0601 - val_acc: 0.9812
# Epoch 160/250
# 238/238 [==============================] - 0s 96us/sample - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0621 - val_acc: 0.9812
# Epoch 161/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0645 - val_acc: 0.9812
# Epoch 162/250
# 238/238 [==============================] - 0s 75us/sample - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0661 - val_acc: 0.9812
# Epoch 163/250
# 238/238 [==============================] - 0s 82us/sample - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0672 - val_acc: 0.9812
# Epoch 164/250
# 238/238 [==============================] - 0s 76us/sample - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0685 - val_acc: 0.9812
# Epoch 165/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0692 - val_acc: 0.9812
# Epoch 166/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0691 - val_acc: 0.9812
# Epoch 167/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0692 - val_acc: 0.9812
# Epoch 168/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0693 - val_acc: 0.9812
# Epoch 169/250
# 238/238 [==============================] - 0s 65us/sample - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0698 - val_acc: 0.9812
# Epoch 170/250
# 238/238 [==============================] - 0s 66us/sample - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0703 - val_acc: 0.9812
# Epoch 171/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0707 - val_acc: 0.9812
# Epoch 172/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0701 - val_acc: 0.9812
# Epoch 173/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0664 - val_acc: 0.9812
# Epoch 174/250
# 238/238 [==============================] - 0s 75us/sample - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0663 - val_acc: 0.9812
# Epoch 175/250
# 238/238 [==============================] - 0s 75us/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0668 - val_acc: 0.9812
# Epoch 176/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0675 - val_acc: 0.9812
# Epoch 177/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0679 - val_acc: 0.9812
# Epoch 178/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0681 - val_acc: 0.9812
# Epoch 179/250
# 238/238 [==============================] - 0s 80us/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0681 - val_acc: 0.9812
# Epoch 180/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0678 - val_acc: 0.9812
# Epoch 181/250
# 238/238 [==============================] - 0s 82us/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0675 - val_acc: 0.9812
# Epoch 182/250
# 238/238 [==============================] - 0s 89us/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0673 - val_acc: 0.9812
# Epoch 183/250
# 238/238 [==============================] - 0s 67us/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0675 - val_acc: 0.9812
# Epoch 184/250
# 238/238 [==============================] - 0s 80us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0703 - val_acc: 0.9812
# Epoch 185/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0713 - val_acc: 0.9812
# Epoch 186/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0715 - val_acc: 0.9812
# Epoch 187/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0714 - val_acc: 0.9812
# Epoch 188/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0712 - val_acc: 0.9812
# Epoch 189/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0711 - val_acc: 0.9812
# Epoch 190/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0711 - val_acc: 0.9812
# Epoch 191/250
# 238/238 [==============================] - 0s 81us/sample - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0712 - val_acc: 0.9812
# Epoch 192/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0713 - val_acc: 0.9812
# Epoch 193/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0714 - val_acc: 0.9812
# Epoch 194/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0714 - val_acc: 0.9812
# Epoch 195/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0711 - val_acc: 0.9812
# Epoch 196/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0710 - val_acc: 0.9812
# Epoch 197/250
# 238/238 [==============================] - 0s 76us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0710 - val_acc: 0.9812
# Epoch 198/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0710 - val_acc: 0.9812
# Epoch 199/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0712 - val_acc: 0.9812
# Epoch 200/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0714 - val_acc: 0.9812
# Epoch 201/250
# 238/238 [==============================] - 0s 79us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0716 - val_acc: 0.9812
# Epoch 202/250
# 238/238 [==============================] - 0s 86us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0719 - val_acc: 0.9812
# Epoch 203/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0722 - val_acc: 0.9812
# Epoch 204/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0726 - val_acc: 0.9812
# Epoch 205/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0729 - val_acc: 0.9812
# Epoch 206/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0732 - val_acc: 0.9812
# Epoch 207/250
# 238/238 [==============================] - 0s 83us/sample - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0738 - val_acc: 0.9812
# Epoch 208/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0742 - val_acc: 0.9812
# Epoch 209/250
# 238/238 [==============================] - 0s 83us/sample - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0745 - val_acc: 0.9812
# Epoch 210/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0748 - val_acc: 0.9812
# Epoch 211/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0750 - val_acc: 0.9812
# Epoch 212/250
# 238/238 [==============================] - 0s 84us/sample - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0751 - val_acc: 0.9812
# Epoch 213/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0751 - val_acc: 0.9812
# Epoch 214/250
# 238/238 [==============================] - 0s 68us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0751 - val_acc: 0.9812
# Epoch 215/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0752 - val_acc: 0.9812
# Epoch 216/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0754 - val_acc: 0.9812
# Epoch 217/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0750 - val_acc: 0.9812
# Epoch 218/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0745 - val_acc: 0.9812
# Epoch 219/250
# 238/238 [==============================] - 0s 87us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0741 - val_acc: 0.9812
# Epoch 220/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0739 - val_acc: 0.9812
# Epoch 221/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0738 - val_acc: 0.9812
# Epoch 222/250
# 238/238 [==============================] - 0s 83us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0739 - val_acc: 0.9812
# Epoch 223/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0738 - val_acc: 0.9812
# Epoch 224/250
# 238/238 [==============================] - 0s 70us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0738 - val_acc: 0.9812
# Epoch 225/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0740 - val_acc: 0.9812
# Epoch 226/250
# 238/238 [==============================] - 0s 74us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0742 - val_acc: 0.9812
# Epoch 227/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0743 - val_acc: 0.9812
# Epoch 228/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0745 - val_acc: 0.9812
# Epoch 229/250
# 238/238 [==============================] - 0s 93us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0749 - val_acc: 0.9812
# Epoch 230/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0751 - val_acc: 0.9812
# Epoch 231/250
# 238/238 [==============================] - 0s 82us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0752 - val_acc: 0.9812
# Epoch 232/250
# 238/238 [==============================] - 0s 82us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0754 - val_acc: 0.9812
# Epoch 233/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0754 - val_acc: 0.9812
# Epoch 234/250
# 238/238 [==============================] - 0s 82us/sample - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0750 - val_acc: 0.9812
# Epoch 235/250
# 238/238 [==============================] - 0s 73us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0747 - val_acc: 0.9812
# Epoch 236/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0745 - val_acc: 0.9812
# Epoch 237/250
# 238/238 [==============================] - 0s 81us/sample - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0744 - val_acc: 0.9812
# Epoch 238/250
# 238/238 [==============================] - 0s 78us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0743 - val_acc: 0.9812
# Epoch 239/250
# 238/238 [==============================] - 0s 82us/sample - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0743 - val_acc: 0.9812
# Epoch 240/250
# 238/238 [==============================] - 0s 86us/sample - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0745 - val_acc: 0.9812
# Epoch 241/250
# 238/238 [==============================] - 0s 75us/sample - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0744 - val_acc: 0.9812
# Epoch 242/250
# 238/238 [==============================] - 0s 76us/sample - loss: 9.8997e-04 - acc: 1.0000 - val_loss: 0.0743 - val_acc: 0.9812
# Epoch 243/250
# 238/238 [==============================] - 0s 71us/sample - loss: 9.7162e-04 - acc: 1.0000 - val_loss: 0.0742 - val_acc: 0.9812
# Epoch 244/250
# 238/238 [==============================] - 0s 76us/sample - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0743 - val_acc: 0.9812
# Epoch 245/250
# 238/238 [==============================] - 0s 72us/sample - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0742 - val_acc: 0.9812
# Epoch 246/250
# 238/238 [==============================] - 0s 77us/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0743 - val_acc: 0.9812
# Epoch 247/250
# 238/238 [==============================] - 0s 69us/sample - loss: 0.0010 - acc: 1.0000 - val_loss: 0.0753 - val_acc: 0.9812
# Epoch 248/250
# 238/238 [==============================] - 0s 76us/sample - loss: 9.5180e-04 - acc: 1.0000 - val_loss: 0.0758 - val_acc: 0.9812
# Epoch 249/250
# 238/238 [==============================] - 0s 74us/sample - loss: 9.8711e-04 - acc: 1.0000 - val_loss: 0.0754 - val_acc: 0.9812
# Epoch 250/250
# 238/238 [==============================] - 0s 71us/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0748 - val_acc: 0.9812

# %% [markdown]
# Plot the training history.

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %% [markdown]
# See how the model performance is.

# %%
from sklearn.metrics import classification_report

predictions = model.predict(x_test)    
print(classification_report(y_test.argmax(-1), predictions.argmax(-1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        61
#            1       0.95      1.00      0.98        61
#            2       1.00      0.92      0.96        38
#
#     accuracy                           0.98       160
#    macro avg       0.98      0.97      0.98       160
# weighted avg       0.98      0.98      0.98       160

# %% [markdown]
# Reset model if new training job is desired.

# %%
#keras.backend.clear_session()

# %% [markdown]
# ### Step 7:
# Export the Keras model to the Tensorflow Protobuf format

# %%
from tensorflow.python.saved_model import builder
from tensorflow.python.saved_model.signature_def_utils import predict_signature_def
from tensorflow.python.saved_model import tag_constants

# Note: This directory structure will need to be followed
model_version = '1'
export_dir = 'export/Servo/' + model_version

# Build the Protocol Buffer SavedModel at 'export_dir'
builder = builder.SavedModelBuilder(export_dir)

# Create prediction signature to be used by TensorFlow Serving Predict API
signature = predict_signature_def(inputs={"inputs": model.input}, outputs={"score": model.output})
from tensorflow.keras import backend as K

with K.get_session() as sess:
    # Save the meta graph and variables
    builder.add_meta_graph_and_variables(sess=sess, tags=[tag_constants.SERVING], 
                                         signature_def_map={"serving_default": signature})
    builder.save()
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: export/Servo/1/saved_model.pb

# %% [markdown]
# ### Step 8:
# Convert TensorFlow model to an Amazon SageMaker-readable format.
#
# Move the TensorFlow exported model into a directory export\Servo. Amazon SageMaker will recognize this as a loadable TensorFlow model. Your directory and file structure should look like this:

# %%
#rm -rf export # if modell was created before, you can removed

# %%
# !ls export
# Out:
# Servo

# %%
# !ls export/Servo
# Out:
# 1

# %%
# !ls export/Servo/1/variables
# Out:
# variables.data-00000-of-00001  variables.index

# %% [markdown]
# Tar the entire directory and upload to Amazon S3

# %%
with tarfile.open('model.tar.gz', mode='w:gz') as archive:
    archive.add('export', recursive=True)

role = sagemaker.get_execution_role()

sagemaker_session = sagemaker.Session()
inputs = sagemaker_session.upload_data(path='model.tar.gz', key_prefix='model')

# %% [markdown]
# ### Step 9:
# Deploy the trained model.
#
# The entry_point file train.py can be an empty Python file.

# %%
# !touch train.py

# %%
from sagemaker.tensorflow.model import TensorFlowModel

sagemaker_model = TensorFlowModel(model_data = 's3://' + sagemaker_session.default_bucket() + '/model/model.tar.gz',
                                  role = role,
                                  framework_version = '1.12',
                                  entry_point = 'train.py')
# Out:
# 2.1.0 is the latest version of tensorflow that supports Python 2. Newer versions of tensorflow will only be available for Python 3.Please set the argument "py_version='py3'" to use the Python 3 tensorflow image.

# %%
# %%time

import time

endpoint_name = "ssv-sagemaker-"+time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())

print(endpoint_name)

predictor = sagemaker_model.deploy(initial_instance_count=1, instance_type="ml.t2.medium",
                                  endpoint_name= endpoint_name)
# Out:
# ssv-sagemaker-2020-04-17-13-07-03
# -------------!CPU times: user 617 ms, sys: 44.3 ms, total: 661 ms
# Wall time: 6min 31s

# %%
from sagemaker.tensorflow.model import TensorFlowModel

predictor=sagemaker.tensorflow.model.TensorFlowPredictor(endpoint_name, sagemaker_session)

# %% [markdown]
# ### Test the model
#
# Step 6. Invoke the endpoint
#
# Invoke the Amazon SageMaker endpoint from the notebook

# %%
data = np.random.randn(1,1800)
r = predictor.predict(data)

output_list = r["outputs"]["score"]["float_val"]
y = np.array(output_list).argmax(axis=-1)

print(y)
# Out:
# 0

# %% [markdown]
# Invoke the Amazon SageMaker endpoint using a boto3 client

# %%
data = np.random.randn(1,1800)
data = data.tolist() 

#endpoint_name = "" # variable with name defined in cell above

client = boto3.client("runtime.sagemaker")
response = client.invoke_endpoint(EndpointName=endpoint_name, Body=json.dumps(data))
response_body = response['Body']
bstr = response_body.read().decode("utf-8") 
    
dbstr = eval(bstr)
output_list = dbstr["outputs"]["score"]["floatVal"]
y = np.array(output_list).argmax(axis=-1)

print(output_list)
print(y)
# Out:
# [0.7774079442024231, 0.0891508087515831, 0.1334412842988968]
# 0

# %% [markdown]
# ### Delete the endpoint

# %%
#predictor.delete_endpoint()
